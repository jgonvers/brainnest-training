# %% [markdown]
# 1. Create a while loop that repeatedly takes user input and adds the input to a list until the user enters "done".

# %%
flag=True
lst=[]
while flag:
    a=input('enter element: ')
    if a=='done':
        flag=False
    else:
        lst=lst+[a]
print(lst)
# Out:
# ['1', '2', 'a']

# %% [markdown]
# 2. Create a while loop that generates random numbers and adds them to a list until the sum of all numbers in the list is greater than 100.

# %%
import random
flag=True
lst=[]
a=0
while flag:
    num=random.random()
    a=a+num
    if a<100:
        lst=lst+[num]
    else:
        flag=False
print(lst)
# Out:
# [0.4288890546751146, 0.5780913011344704, 0.20609823213950174, 0.81332125135732, 0.8235888725334455, 0.6534725339011758, 0.16022955651881965, 0.5206693596399246, 0.32777281162209315, 0.24999667668640035, 0.9528169091459117, 0.9965569925394552, 0.04455638245043303, 0.860161037286291, 0.603190610968185, 0.3816059859191179, 0.28361821790671515, 0.674964847134956, 0.45683115105830563, 0.6858614854745947, 0.6618463200523511, 0.1329781447122128, 0.7678378139439905, 0.9824132490111909, 0.9693881604049188, 0.613326820546709, 0.0442606328646209, 0.004055144158407464, 0.13397252704913387, 0.941002271395834, 0.3028605620290723, 0.3661456016604264, 0.8981962445391883, 0.31436380495645067, 0.5489821840124055, 0.43603095762412225, 0.06499417612685054, 0.5845462257019302, 0.8440678976619022, 0.1564189183874064, 0.2242989686860415, 0.41287020771484073, 0.03692486905862902, 0.4966034986165482, 0.8179828644296319, 0.6578909387591091, 0.5334837356527721, 0.8551257407736, 0.14968813497140154, 0.5672354768631239, 0.3741748177480889, 0.6013045471136395, 0.11291570189443623, 0.7755127010728279, 0.09660583318435267, 0.16636374579324753, 0.8074497520247557, 0.9476939242234907, 0.4332315025514858, 0.41408083174830124, 0.24548187614075512, 0.274703391965577, 0.6172527709741663, 0.17846041072072527, 0.11948250433077712, 0.45573485868103825, 0.1649378065796322, 0.648724831216227, 0.821055674361497, 0.7775113893753993, 0.48013339022434753, 0.34757125622081697, 0.4347105489944344, 0.005008574909348362, 0.7125732007896374, 0.33165722263549546, 0.31942323776053394, 0.07992503242021254, 0.44805592600101607, 0.5828489673005941, 0.390586941842884, 0.8695455453974028, 0.6733532167485129, 0.2414082418108049, 0.5253538488765902, 0.9105338176465975, 0.5201096943214129, 0.6021048687389493, 0.06277362381152096, 0.48938611652176434, 0.4614412627964344, 0.4011298800689024, 0.4204353581465221, 0.5849350493343958, 0.5386670484231432, 0.4898957587909363, 0.16579644053220766, 0.4413468174535875, 0.9686781985609425, 0.4151736932178327, 0.035317829787831156, 0.002830426682370324, 0.5354184513162129, 0.05057294182209637, 0.09274340534219172, 0.10875641262696911, 0.4540783303488197, 0.9926880657637538, 0.48505535080507134, 0.4586402838083844, 0.4365108145371187, 0.5011121848422556, 0.4470874692740242, 0.726215200566661, 0.8979415356273188, 0.6978703473377672, 0.42331060266774045, 0.6495291182373754, 0.9095405975236686, 0.15362734153599478, 0.2373424569000443, 0.6191120001144675, 0.6870199456481508, 0.6426002227117794, 0.5885285628983279, 0.8294231938453709, 0.4789429532356768, 0.8075888612596384, 0.9623558468839565, 0.43535668292056506, 0.8588455784808138, 0.7182423791983076, 0.8886814943629995, 0.04623588619564345, 0.9130986448423635, 0.7668385355448595, 0.9623789273619899, 0.98131935906942, 0.28548573078687023, 0.6700013166466804, 0.14127353102702234, 0.5951327636887873, 0.9195796756956715, 0.19197332103443343, 0.3498686863671552, 0.07974567705000712, 0.19465631564517616, 0.20770266641880264, 0.09600092980546204, 0.9996980377175202, 0.8875339549944073, 0.46375997262576707, 0.7437024470523893, 0.695236793364116, 0.522454609889347, 0.42348679488615915, 0.664073323782122, 0.5555198729672033, 0.265889827888687, 0.3643255465919335, 0.6272667630222782, 0.6271288917045859, 0.2095937611451607, 0.6097729907070338, 0.8749287603932815, 0.8713374496408887, 0.6522633075694795, 0.07017267325726095, 0.42351808992862205, 0.08902228492414066, 0.05524979791048534, 0.2546980854885439, 0.45687376278766356, 0.7593995049120491, 0.6288415398407439, 0.28248460193485714, 0.6950690619200575, 0.5065069608344968, 0.5075296156707131, 0.2636220634323303, 0.441645686622701, 0.3415258701814652, 0.726546393909013, 0.4825965308099226, 0.44676557819006135, 0.47700809379806863, 0.47991137269101614, 0.6896387006328037, 0.7198476893232635, 0.8010969737326715, 0.40525688164589924, 0.7935398606099887, 0.9647259459117272, 0.9923494116644874, 0.7206556019502786, 0.06548864838133828, 0.8472865278538246]

# %% [markdown]
# 3. Create a while loop that repeatedly takes user input and appends it to a list, but only if the input is a unique string.

# %%
flag=True
lst=[]
while flag:
    a=input('enter a string? ')
    if a in lst:
        flag=False
    else:
        lst=lst+[a]
print(lst)
# Out:
# ['a', '12', 's', 'd']

# %% [markdown]
# 4. Create a while loop that repeatedly takes user input and appends it to a list, but only if the input is a number greater than 10.

# %%
flag=True
lst=[]
try:
    while flag:
        a=int(input('enter a number? '))
        if a<=10:
            flag=False
        else:
            lst=lst+[a]
    print(lst)
except:
    print('wrong input')
# Out:
# [15, 14, 802]

# %% [markdown]
# 5. Create a while loop that repeatedly takes user input and keeps track of the highest number entered until the user enters "done".

# %%
flag=True
lst=[]
try:
    while flag:
        a=input('input? ')
        if a=='done':
            flag=False
        else:
            a=int(a)
            lst=lst+[a]
            maxx=max(lst)
    print('list of input numbers and maximum number are: ' , lst , maxx)
except:
    print('wrong input')
# Out:
# list of input numbers and maximum number are:  [12, 105, 1002] 1002
